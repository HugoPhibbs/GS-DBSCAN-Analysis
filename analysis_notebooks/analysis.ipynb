# %%
import importlib
import src.experiment as exp
importlib.reload(exp)
# Out:
# <module 'src.experiment' from '/home/hphi344/Documents/GS-DBSCAN-Analysis/src/experiment.py'>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

distance_batch_sizes = [10, 50, 100, 150, 200, 250, 300]
# distance_batch_sizes = [10, 500]

results_df = exp.run_batch_experiments(distance_batch_sizes, k = 2, m = 2000, write_to_pickle=True)

def display_batch_experiments_results(results_df):
    total_times = np.array([times["overall"] for times in results_df["times"]]) / 1e6
    distances_times = np.array([times["distances"] for times in results_df["times"]]) / 1e6

    distance_batch_sizes = results_df["batchSize"].values

    batches_df = pd.DataFrame({"batchSize": distance_batch_sizes, "totalTime": total_times, "nmi": results_df["nmi"],
                                "distancesTime": distances_times})

    plt.plot(batches_df["batchSize"], batches_df["totalTime"])
    plt.xscale
    plt.xlabel("Batch Size")
    plt.ylabel("Total Time (ms)")
    plt.title("Total Time vs Batch Size")
    plt.ion()
    plt.show()

display_batch_experiments_results(results_df)
# Out:
# Running GS-DBSCAN
#
# ['/home/hphi344/Documents/GS-DBSCAN-Analysis/../GS-DBSCAN-CPP/build-release/GS-DBSCAN', '--datasetFilename', '/home/hphi344/Documents/GS-DBSCAN-Analysis/data/mnist_images_col_major.bin', '--outFile', '/home/hphi344/Documents/GS-DBSCAN-Analysis/results/batch_experiments/results_n70000_d784_D1024_mp50_k2_m2000_e0.11_a1.2_dbs10_dmCOSINE_cbs256_coc0_nn1.json', '--n', '70000', '--d', '784', '--D', '1024', '--minPts', '50', '--k', '2', '--m', '2000', '--eps', '0.11', '--alpha', '1.2', '--distancesBatchSize', '10', '--distanceMetric', 'COSINE', '--clusterBlockSize', '256', '--clusterOnCpu', '1', '--needToNormalize', '1']
# Standard Output:
#  Args: {
#     "D": 1024,
#     "alpha": 1.2000000476837158,
#     "clusterBlockSize": 256,
#     "clusterOnCpu": true,
#     "d": 784,
#     "datasetFilename": "/home/hphi344/Documents/GS-DBSCAN-Analysis/data/mnist_images_col_major.bin",
#     "distanceMetric": "COSINE",
#     "distancesBatchSize": 10,
#     "eps": 0.10999999940395355,
#     "k": 2,
#     "m": 2000,
#     "minPts": 50,
#     "n": 70000,
#     "needToNormalize": true,
#     "outFile": "/home/hphi344/Documents/GS-DBSCAN-Analysis/results/batch_experiments/results_n70000_d784_D1024_mp50_k2_m2000_e0.11_a1.2_dbs10_dmCOSINE_cbs256_coc0_nn1.json"
# }
# Times: {
#     "copyingAndConvertData": 518731,
#     "projectionsAndNormalize": 118082,
#     "constructABMatrices": 105432,
#     "distances": 10902873,
#     "matXToTorch": 4,
#     "degArray": 6652,
#     "startIdxArray": 28094,
#     "adjacencyList": 26246,
#     "copyClusteringArrays": 12536,
#     "processAdjacencyList": 371828,
#     "formClusters": 7635,
#     "clusteringOverall": 441064,
#     "overall": 12086201
# }
# NumClusters: 6
#
# Execution successful
# Running GS-DBSCAN
#
# ['/home/hphi344/Documents/GS-DBSCAN-Analysis/../GS-DBSCAN-CPP/build-release/GS-DBSCAN', '--datasetFilename', '/home/hphi344/Documents/GS-DBSCAN-Analysis/data/mnist_images_col_major.bin', '--outFile', '/home/hphi344/Documents/GS-DBSCAN-Analysis/results/batch_experiments/results_n70000_d784_D1024_mp50_k2_m2000_e0.11_a1.2_dbs50_dmCOSINE_cbs256_coc0_nn1.json', '--n', '70000', '--d', '784', '--D', '1024', '--minPts', '50', '--k', '2', '--m', '2000', '--eps', '0.11', '--alpha', '1.2', '--distancesBatchSize', '50', '--distanceMetric', 'COSINE', '--clusterBlockSize', '256', '--clusterOnCpu', '1', '--needToNormalize', '1']
# Standard Output:
#  Args: {
#     "D": 1024,
#     "alpha": 1.2000000476837158,
#     "clusterBlockSize": 256,
#     "clusterOnCpu": true,
#     "d": 784,
#     "datasetFilename": "/home/hphi344/Documents/GS-DBSCAN-Analysis/data/mnist_images_col_major.bin",
#     "distanceMetric": "COSINE",
#     "distancesBatchSize": 50,
#     "eps": 0.10999999940395355,
#     "k": 2,
#     "m": 2000,
#     "minPts": 50,
#     "n": 70000,
#     "needToNormalize": true,
#     "outFile": "/home/hphi344/Documents/GS-DBSCAN-Analysis/results/batch_experiments/results_n70000_d784_D1024_mp50_k2_m2000_e0.11_a1.2_dbs50_dmCOSINE_cbs256_coc0_nn1.json"
# }
# Times: {
#     "copyingAndConvertData": 393311,
#     "projectionsAndNormalize": 114144,
#     "constructABMatrices": 103283,
#     "distances": 10805642,
#     "matXToTorch": 9,
#     "degArray": 6129,
#     "startIdxArray": 28137,
#     "adjacencyList": 26219,
#     "copyClusteringArrays": 12282,
#     "processAdjacencyList": 375873,
#     "formClusters": 7779,
#     "clusteringOverall": 444752,
#     "overall": 11861157
# }
# NumClusters: 6
#
# Execution successful
# Running GS-DBSCAN
#
# ['/home/hphi344/Documents/GS-DBSCAN-Analysis/../GS-DBSCAN-CPP/build-release/GS-DBSCAN', '--datasetFilename', '/home/hphi344/Documents/GS-DBSCAN-Analysis/data/mnist_images_col_major.bin', '--outFile', '/home/hphi344/Documents/GS-DBSCAN-Analysis/results/batch_experiments/results_n70000_d784_D1024_mp50_k2_m2000_e0.11_a1.2_dbs100_dmCOSINE_cbs256_coc0_nn1.json', '--n', '70000', '--d', '784', '--D', '1024', '--minPts', '50', '--k', '2', '--m', '2000', '--eps', '0.11', '--alpha', '1.2', '--distancesBatchSize', '100', '--distanceMetric', 'COSINE', '--clusterBlockSize', '256', '--clusterOnCpu', '1', '--needToNormalize', '1']
# Standard Output:
#  Args: {
#     "D": 1024,
#     "alpha": 1.2000000476837158,
#     "clusterBlockSize": 256,
#     "clusterOnCpu": true,
#     "d": 784,
#     "datasetFilename": "/home/hphi344/Documents/GS-DBSCAN-Analysis/data/mnist_images_col_major.bin",
#     "distanceMetric": "COSINE",
#     "distancesBatchSize": 100,
#     "eps": 0.10999999940395355,
#     "k": 2,
#     "m": 2000,
#     "minPts": 50,
#     "n": 70000,
#     "needToNormalize": true,
#     "outFile": "/home/hphi344/Documents/GS-DBSCAN-Analysis/results/batch_experiments/results_n70000_d784_D1024_mp50_k2_m2000_e0.11_a1.2_dbs100_dmCOSINE_cbs256_coc0_nn1.json"
# }
# Times: {
#     "copyingAndConvertData": 398308,
#     "projectionsAndNormalize": 117528,
#     "constructABMatrices": 102419,
#     "distances": 10816263,
#     "matXToTorch": 4,
#     "degArray": 6232,
#     "startIdxArray": 28088,
#     "adjacencyList": 26371,
#     "copyClusteringArrays": 13198,
#     "processAdjacencyList": 390988,
#     "formClusters": 7681,
#     "clusteringOverall": 459981,
#     "overall": 11894519
# }
# NumClusters: 6
#
# Execution successful
# Running GS-DBSCAN
#
# ['/home/hphi344/Documents/GS-DBSCAN-Analysis/../GS-DBSCAN-CPP/build-release/GS-DBSCAN', '--datasetFilename', '/home/hphi344/Documents/GS-DBSCAN-Analysis/data/mnist_images_col_major.bin', '--outFile', '/home/hphi344/Documents/GS-DBSCAN-Analysis/results/batch_experiments/results_n70000_d784_D1024_mp50_k2_m2000_e0.11_a1.2_dbs150_dmCOSINE_cbs256_coc0_nn1.json', '--n', '70000', '--d', '784', '--D', '1024', '--minPts', '50', '--k', '2', '--m', '2000', '--eps', '0.11', '--alpha', '1.2', '--distancesBatchSize', '150', '--distanceMetric', 'COSINE', '--clusterBlockSize', '256', '--clusterOnCpu', '1', '--needToNormalize', '1']
# Standard Output:
#  Args: {
#     "D": 1024,
#     "alpha": 1.2000000476837158,
#     "clusterBlockSize": 256,
#     "clusterOnCpu": true,
#     "d": 784,
#     "datasetFilename": "/home/hphi344/Documents/GS-DBSCAN-Analysis/data/mnist_images_col_major.bin",
#     "distanceMetric": "COSINE",
#     "distancesBatchSize": 150,
#     "eps": 0.10999999940395355,
#     "k": 2,
#     "m": 2000,
#     "minPts": 50,
#     "n": 70000,
#     "needToNormalize": true,
#     "outFile": "/home/hphi344/Documents/GS-DBSCAN-Analysis/results/batch_experiments/results_n70000_d784_D1024_mp50_k2_m2000_e0.11_a1.2_dbs150_dmCOSINE_cbs256_coc0_nn1.json"
# }
# Times: {
#     "copyingAndConvertData": 402884,
#     "projectionsAndNormalize": 117765,
#     "constructABMatrices": 105705,
#     "distances": 10818593,
#     "matXToTorch": 4,
#     "degArray": 6387,
#     "startIdxArray": 28223,
#     "adjacencyList": 26446,
#     "copyClusteringArrays": 12887,
#     "processAdjacencyList": 382925,
#     "formClusters": 7797,
#     "clusteringOverall": 452395,
#     "overall": 11897366
# }
# NumClusters: 6
#
# Execution successful
# Running GS-DBSCAN
#
# ['/home/hphi344/Documents/GS-DBSCAN-Analysis/../GS-DBSCAN-CPP/build-release/GS-DBSCAN', '--datasetFilename', '/home/hphi344/Documents/GS-DBSCAN-Analysis/data/mnist_images_col_major.bin', '--outFile', '/home/hphi344/Documents/GS-DBSCAN-Analysis/results/batch_experiments/results_n70000_d784_D1024_mp50_k2_m2000_e0.11_a1.2_dbs200_dmCOSINE_cbs256_coc0_nn1.json', '--n', '70000', '--d', '784', '--D', '1024', '--minPts', '50', '--k', '2', '--m', '2000', '--eps', '0.11', '--alpha', '1.2', '--distancesBatchSize', '200', '--distanceMetric', 'COSINE', '--clusterBlockSize', '256', '--clusterOnCpu', '1', '--needToNormalize', '1']
# Standard Output:
#  Args: {
#     "D": 1024,
#     "alpha": 1.2000000476837158,
#     "clusterBlockSize": 256,
#     "clusterOnCpu": true,
#     "d": 784,
#     "datasetFilename": "/home/hphi344/Documents/GS-DBSCAN-Analysis/data/mnist_images_col_major.bin",
#     "distanceMetric": "COSINE",
#     "distancesBatchSize": 200,
#     "eps": 0.10999999940395355,
#     "k": 2,
#     "m": 2000,
#     "minPts": 50,
#     "n": 70000,
#     "needToNormalize": true,
#     "outFile": "/home/hphi344/Documents/GS-DBSCAN-Analysis/results/batch_experiments/results_n70000_d784_D1024_mp50_k2_m2000_e0.11_a1.2_dbs200_dmCOSINE_cbs256_coc0_nn1.json"
# }
# Times: {
#     "copyingAndConvertData": 398823,
#     "projectionsAndNormalize": 114975,
#     "constructABMatrices": 105646,
#     "distances": 10826451,
#     "matXToTorch": 8,
#     "degArray": 6074,
#     "startIdxArray": 28426,
#     "adjacencyList": 26245,
#     "copyClusteringArrays": 12233,
#     "processAdjacencyList": 376135,
#     "formClusters": 7663,
#     "clusteringOverall": 445171,
#     "overall": 11891091
# }
# NumClusters: 6
#
# Execution successful
# Running GS-DBSCAN
#
# ['/home/hphi344/Documents/GS-DBSCAN-Analysis/../GS-DBSCAN-CPP/build-release/GS-DBSCAN', '--datasetFilename', '/home/hphi344/Documents/GS-DBSCAN-Analysis/data/mnist_images_col_major.bin', '--outFile', '/home/hphi344/Documents/GS-DBSCAN-Analysis/results/batch_experiments/results_n70000_d784_D1024_mp50_k2_m2000_e0.11_a1.2_dbs250_dmCOSINE_cbs256_coc0_nn1.json', '--n', '70000', '--d', '784', '--D', '1024', '--minPts', '50', '--k', '2', '--m', '2000', '--eps', '0.11', '--alpha', '1.2', '--distancesBatchSize', '250', '--distanceMetric', 'COSINE', '--clusterBlockSize', '256', '--clusterOnCpu', '1', '--needToNormalize', '1']
# Standard Output:
#  Args: {
#     "D": 1024,
#     "alpha": 1.2000000476837158,
#     "clusterBlockSize": 256,
#     "clusterOnCpu": true,
#     "d": 784,
#     "datasetFilename": "/home/hphi344/Documents/GS-DBSCAN-Analysis/data/mnist_images_col_major.bin",
#     "distanceMetric": "COSINE",
#     "distancesBatchSize": 250,
#     "eps": 0.10999999940395355,
#     "k": 2,
#     "m": 2000,
#     "minPts": 50,
#     "n": 70000,
#     "needToNormalize": true,
#     "outFile": "/home/hphi344/Documents/GS-DBSCAN-Analysis/results/batch_experiments/results_n70000_d784_D1024_mp50_k2_m2000_e0.11_a1.2_dbs250_dmCOSINE_cbs256_coc0_nn1.json"
# }
# Times: {
#     "copyingAndConvertData": 410022,
#     "projectionsAndNormalize": 117808,
#     "constructABMatrices": 103062,
#     "distances": 10835029,
#     "matXToTorch": 5,
#     "degArray": 6202,
#     "startIdxArray": 28255,
#     "adjacencyList": 26628,
#     "copyClusteringArrays": 13478,
#     "processAdjacencyList": 390330,
#     "formClusters": 7733,
#     "clusteringOverall": 459768,
#     "overall": 11925709
# }
# NumClusters: 6
#
# Execution successful
# Running GS-DBSCAN
#
# ['/home/hphi344/Documents/GS-DBSCAN-Analysis/../GS-DBSCAN-CPP/build-release/GS-DBSCAN', '--datasetFilename', '/home/hphi344/Documents/GS-DBSCAN-Analysis/data/mnist_images_col_major.bin', '--outFile', '/home/hphi344/Documents/GS-DBSCAN-Analysis/results/batch_experiments/results_n70000_d784_D1024_mp50_k2_m2000_e0.11_a1.2_dbs300_dmCOSINE_cbs256_coc0_nn1.json', '--n', '70000', '--d', '784', '--D', '1024', '--minPts', '50', '--k', '2', '--m', '2000', '--eps', '0.11', '--alpha', '1.2', '--distancesBatchSize', '300', '--distanceMetric', 'COSINE', '--clusterBlockSize', '256', '--clusterOnCpu', '1', '--needToNormalize', '1']
# Standard Output:
#  Args: {
#     "D": 1024,
#     "alpha": 1.2000000476837158,
#     "clusterBlockSize": 256,
#     "clusterOnCpu": true,
#     "d": 784,
#     "datasetFilename": "/home/hphi344/Documents/GS-DBSCAN-Analysis/data/mnist_images_col_major.bin",
#     "distanceMetric": "COSINE",
#     "distancesBatchSize": 300,
#     "eps": 0.10999999940395355,
#     "k": 2,
#     "m": 2000,
#     "minPts": 50,
#     "n": 70000,
#     "needToNormalize": true,
#     "outFile": "/home/hphi344/Documents/GS-DBSCAN-Analysis/results/batch_experiments/results_n70000_d784_D1024_mp50_k2_m2000_e0.11_a1.2_dbs300_dmCOSINE_cbs256_coc0_nn1.json"
# }
# Times: {
#     "copyingAndConvertData": 410901,
#     "projectionsAndNormalize": 117639,
#     "constructABMatrices": 93274,
#     "distances": 10838256,
#     "matXToTorch": 5,
#     "degArray": 6312,
#     "startIdxArray": 28290,
#     "adjacencyList": 26247,
#     "copyClusteringArrays": 12971,
#     "processAdjacencyList": 387388,
#     "formClusters": 7753,
#     "clusteringOverall": 456599,
#     "overall": 11916692
# }
# NumClusters: 6
#
# Execution successful
